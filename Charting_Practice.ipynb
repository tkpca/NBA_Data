# %%
import numpy as np
import numpy as np
import pandas as pd

import cufflinks as py

import chart_studio as cs
import chart_studio.tools as tls
import plotly.graph_objs as go
import plotly.io as pio
import plotly.express as px

cs.tools.set_credentials_file(username='tkpca', api_key='br6zLpCvAoJJhjnnmOYx') #login with api key
pd.options.display.float_format = '{:,.2f}'.format
pd.set_option('display.max_columns', None)

# %%
# for the player's photo url is https://ak-static.cms.nba.com/wp-content/uploads/headshots/nba/latest/260x190/ + the PLAYER_ID

# %%
df=pd.read_hdf('2018-2019_data.h5')

# %%
df.head()
# Out:
#       GAME_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_ID       PLAYER_NAME  \
# 0  0021800001  1610612755               PHI     203967       Dario Saric
# 1  0021800001  1610612755               PHI     203496  Robert Covington
# 2  0021800001  1610612755               PHI     203954       Joel Embiid
# 3  0021800001  1610612755               PHI    1628365    Markelle Fultz
# 4  0021800001  1610612755               PHI    1627732       Ben Simmons
#
#   START_POSITION COMMENT  FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM   FTA  \
# 0              F         3.00  8.00    0.38  0.00  4.00     0.00 0.00  0.00
# 1              F         3.00 10.00    0.30  2.00  7.00     0.29 0.00  0.00
# 2              C         9.00 21.00    0.43  1.00  4.00     0.25 4.00  5.00
# 3              G         2.00  7.00    0.29  0.00  0.00     0.00 1.00  2.00
# 4              G         7.00 14.00    0.50  0.00  0.00     0.00 5.00 10.00
#
# ...

# %%
temp_df=df.groupby(['TEAM_ABBREVIATION','GAME_ID'])['PLAYER_WIN_OR_LOSE'].max().reset_index()
temp_df.groupby('TEAM_ABBREVIATION')['PLAYER_WIN_OR_LOSE'].sum().sort_values(ascending=False)
# Out:
# TEAM_ABBREVIATION
# CHI    72
# SEA    64
# ORL    60
# SAN    59
# UTH    55
# LAL    53
# IND    52
# HOU    48
# CLE    47
# NYK    47
# ATL    46
# DET    46
# POR    44
# MIA    42
# CHH    41
# PHX    41
# WAS    39
# SAC    39
# GOS    36
# DEN    35
# BOS    33
# NJN    30
# LAC    29
# MIN    26
# DAL    26
# MIL    25
# TOR    21
# PHL    18
# VAN    15
# Name: PLAYER_WIN_OR_LOSE, dtype: int32

# %%
nba_select=df[(df.PLAYER_NAME=='Michael Jordan') & (df.MIN_PLAY>1)]
nba_select.head()
# Out:
#          GAME_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_ID     PLAYER_NAME  \
# 5     0029500001  1610612741               CHI        893  Michael Jordan
# 365   0029500018  1610612741               CHI        893  Michael Jordan
# 720   0029500035  1610612741               CHI        893  Michael Jordan
# 1108  0029500053  1610612741               CHI        893  Michael Jordan
# 1529  0029500074  1610612741               CHI        893  Michael Jordan
#
#      START_POSITION COMMENT  FGM  FGA  FG_PCT  ...  PF  PTS  PLUS_MINUS  \
# 5                             16   29    0.55  ...   4   42         nan
# 365                            5   12    0.42  ...   4   15         nan
# 720                           13   19    0.68  ...   2   38         nan
# 1108                          12   24    0.50  ...   3   29         nan
# 1529                          11   23    0.48  ...   3   36         nan
#
#       GAME_DATE_EST  HM_AW  MIN_PLAY  SEC_PLAY  OPP  WINNER  \
# ...

# %%
nba_select[['PTS','TO','AST']].mean()
# Out:
# PTS   30.38
# TO     2.40
# AST    4.29
# dtype: float64

# %%
fig = px.scatter(nba_select, x="MIN_PLAY", y="FG_PCT",color='OPP')
fig.update_xaxes(title_text='Mins Played', type='log')
fig.update_yaxes(title_text='FG%')

pio.write_html(fig, file='hello_world.html', auto_open=True)

# %%
df.columns

# %%
nba_select=df[(df.PLAYER_NAME=='Joel Embiid') & ~(df.MIN_PLAY>0)]
nba_select.head()

# %%
beep_sound()

# %%
nba_select=df[(df.PLAYER_NAME=='Joel Embiid')]
nba_select
